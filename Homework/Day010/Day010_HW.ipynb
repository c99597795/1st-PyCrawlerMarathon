# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'
r=requests.get(url)
soup=BeautifulSoup(r.text,'html.parser')
print(soup.prettify()[0:1000])
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
#  <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">
#   <title data-react-helmet="true">
#    Dcard
#   </title>
#   <meta content="https://www.dcard.tw/build/landing-c9e7b8fb.png" data-react-helmet="true" property="og:image"/>
#   <meta content="https://www.dcard.tw/build/landing-c9e7b8fb.png" data-react-helmet="true" property="og:image:secure_url"/>
#   <meta charset="utf-8" data-react-helmet="true"/>
#   <meta content="IE=edge" data-react-helmet="true" http-equiv="X-UA-Compatible"/>
#   <meta content="Dcard" data-react-helmet="true" name="application-name"/>
#   <meta content="app-id=951353454" data-react-helmet="true" name="apple-itunes-app"/>
#   <meta content="#006aa6" data-react-helmet="true" name="theme-color"/>
#   <meta content="yes" data-react-helmet="true" name="mobile-web-app-capable"/>
#   <meta content="yes" data-react-helmet="true" name="apple-mobile-web-app-capable"/>
#   <meta content="211628828926493" data-react-he

# %% [markdown]
# ## Grab + PyQuery

# %%
from grab import Grab
g = Grab()
resp = g.go('https://www.dcard.tw/f')

# %%
from pyquery import PyQuery as pq
doc = pq(resp.body)
title = doc('body')
print(type(title), title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'> 登入
# 更多
# 看板列表
# 全部
# 武漢肺炎
# 新年快樂
# YouTuber
# 官方公告
# 小事公益
# 新生季
# 美妝
# 美甲
# 醫美
# 香氛
# 美髮
# 牙齒矯正
# 隱形眼鏡
# 穿搭
# 球鞋
# 網路購物
# 精品
# 感情
# 心情
# 閒聊
# 有趣
# 笑話
# 梗圖
# 女孩
# 生理用品
# 結婚
# 親子
# 彩虹
# 跨性別
# 偽娘
# Les
# 追星
# BTS
# AKB48 集團
# 乃木坂 46
# 韓星
# EXO
# 五月天
# 麥可傑克森
# 手作
# 插畫
# 設計
# 手寫
# 文具
# 玩具
# 樂高
# 居家生活
# 建築
# 芳療
# 無痕生活
# 寵物
# 曬貓
# 攝影
# 植物
# 汽機車
# 重機
# 航空
# 鐵道
# 交通運輸
# 星座
# 塔羅
# 靈異
# 美食
# 烹飪
# 手搖
# 品酒
# 咖啡
# 呷菜
# 速食
# 零食
# 超商
# 量販店
# 旅遊
# 電影
# 戲劇綜藝
# 歐美影集
# Netflix
# 漫威
# 日劇
# 韓綜
# 音樂
# 獨立音樂
# 電子音樂
# 音樂活動
# 管樂
# 嘻哈
# 復古
# 布袋戲
# 劇場
# 遊戲
# 桌遊
# 爐石戰記
# 陰陽師
# Minecraft
# 英雄聯盟
# 動漫
# BL
# 百合
# Cosplay
# 寶可夢
# 迪士尼
# 柯南
# 航海王
# 卡娜赫拉
# 蠟筆小新
# 運動
# 棒球
# 中職
# 網球
# 足球
# 籃球
# 羽球
# 排球
# 桌球
# 舞蹈
# 健身
# 減肥
# 自由潛水
# 單車
# 大型賽事
# 身心障礙
# 男孩
# 軍旅
# 3C
# App
# 智慧家庭
# Apple
# 視聽設備
# 理財
# 信用卡
# 省錢
# 行動支付
# 區塊鏈
# 金融
# 時事
# 工作
# 護理
# 醫事人員
# 軟體工程師
# 前端工程師
# 創客
# 科學
# 日本生活
# 打工職缺
# 實習職缺
# 留學
# 韓國留學
# 課程
# 研究所
# 考試
# 會計
# 公職
# 語言
# 書籍
# 小說
# 詩文
# 台中
# 高雄
# 災害回報
# 建議回饋
# 西斯
# 西斯文學
# 男同志西斯
# 色情漫畫
# BDSM
# 校園看板
# 臺灣大學
# 政治大學
# 交通大學
# 淡江大學
# 東華大學
# 成功大學
# 北科大
# 輔仁大學
# 師範大學
# 高雄師範大學
# 彰化師範大學
# 中央大學
# 逢甲大學
# 清華大學
# 暨南大學
# 東海大學
# 高雄第一科大
# 台科大
# 中興大學
# 元智大學
# 聯合大學
# 海洋大學
# 中山大學
# 臺北大學
# 中央警察大學
# 中正大學
# 實踐大學
# 陽明大學
# 臺灣藝術大學
# 世新大學
# 臺北教育大學
# 臺北藝術大學
# 臺北市立大學
# 文化大學
# 東吳大學
# 嘉義大學
# 高雄大學
# 中科大
# 國北護
# 義守大學
# 長庚大學
# 臺北醫學大學
# 中原大學
# 中山醫學大學
# 文藻外語大學
# 高應大
# 長庚科大
# 勤益科大
# 銘傳大學
# 宜蘭大學
# 虎尾科大
# 新竹教育大學
# 大同大學
# 臺北商業大學
# 臺中教育大學
# 屏東大學
# 靜宜大學
# 高雄海洋科大
# 朝陽科大
# 國防大學
# 南臺科大
# 高雄餐旅大學
# 中國醫藥大學
# 長榮大學
# 屏科大
# 明志科大
# 亞洲大學
# 健行科大
# 樹德科技大學
# 真理大學
# 嘉南藥理大學
# 高雄醫學大學
# 明新科技大學
# 臺東大學
# 台南應用科大
# 金門大學
# 大葉大學
# 南華大學
# 嶺東科大
# 輔英科技大學
# 中國科大
# 慈濟科技大學
# 慈濟大學
# 致理科技大學
# 開南大學
# 弘光科技大學
# 臺南大學
# 中華大學
# 德明財經科大
# 景文科大
# 龍華科技大學
# 國立雲林科技大學
# 正修科大
# 遠東科大
# 吳鳳科大
# 中臺科大
# 國立澎湖科技大學
# 崑山科大
# 中華醫事科技大學
# 僑光科技大學
# 環球科技大學
# 臺灣體育運動大學
# 醒吾科技大學
# 華梵大學
# 佛光大學
# 萬能科大
# 亞東技術學院
# 經國管理暨健康學院
# 建國科大
# 東南科大
# 南開科大
# 聖約翰科大
# 明道大學
# 美和科大
# 臺南藝術大學
# 康寧大學
# 育達科大
# 高苑科大
# 中華科大
# 元培醫事科大
# 國立體育大學
# 大仁科大
# 台灣首府大學
# 玄奘大學
# 南榮科大
# 中州科大
# 華夏科大
# 修平科大
# 大華科大
# 臺北城市科大
# 馬偕醫學院
# 宏國德霖科技大學
# 台北海洋科技大學
# 南亞技術學院
# 臺灣戲曲學院
# 黎明技術學院
# 稻江科技暨管理學院
# 大漢技術學院
# 臺灣觀光學院
# 蘭陽技術學院
# 亞太創意技術學院
# 大同技術學院
# 法鼓文理學院
# 和春技術學院
# 東方設計大學
# 崇右影藝科技大學
# 康寧醫護暨管理專科學校
# 聖母醫護管理專科學校
# 高美醫護管理專科學校
# 育英醫護管理專科學校
# 國立臺南護理專科學校
# 慈惠醫護管理專科學校
# 新生醫護管理專科學校
# 馬偕醫護管理專科學校
# 耕莘健康管理專科學校
# 樹人醫護管理專科學校
# 仁德醫護管理專科學校
# 崇仁醫護管理專科學校
# 敏惠醫護管理專科學校
# 國防醫學院
# 中華民國陸軍專科學校
# 臺灣警察專科學校
# 國立高雄科技大學
# 中信金融管理學院
# 國立臺東專科學校
# 中華民國海軍軍官學校
# 空軍航空技術學院
# 香港中文大學
# 香港大學
# 香港科技大學
# 香港理工大學
# 香港浸會大學
# 香港城市大學
# 香港嶺南大學
# 香港樹仁大學
# 香港恒生大學
# 香港公開大學
# 香港教育大學
# 看板管理
# 看板設定
# 看板資訊
# 板規設定
# 板規與違規項目設定
# .cls-3{fill:#ea5c5c}
# 站規之禁言天數設定
# 文章管理
# 文章檢舉
# 留言檢舉
# 其他
# 管理活動記錄
# {"@context":"https://schema.org","@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的--Dcard--是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}
# 全部追蹤
# 文章排序依
# 熱門
# C
# 武漢肺炎
# 板務小天使
# 2月5日 13:10
# 置頂
# 感謝不斷電⚡️守護台灣的你們辛苦了，Dcard 打氣文募集中！
# 昨天看到阿中部長落淚，有在螢幕前跟著哭的舉手，武漢肺炎爆發到現在，除了第一線檢疫、醫護人員們不眠不休防堵疫情擴散，也有許多默默付出的無名英雄值得收到大家的鼓勵，像是萬能的超商店員、接下來可能會忙翻天的
# 7449
# 回應956
# 收藏
# E
# 時事
# 湯麵趁熱吃
# 2月5日 12:23
# 大S徹底把台灣人用臭了
# 剛剛看到這篇文章，上次的口罩事件讓日本人很不爽，誰來告訴日本人她不是台灣人啊，台灣的名聲都被她弄臭了
# 12527
# 回應797
# 收藏
# 心情
# 匿名
# 2月5日 16:02
# 我弟同時搞大三個女生的肚子
# 我弟今年23歲，專情兩字應該跟他是絕緣體，昨天忽然異常安靜的在客廳坐著，我們就知道沒好事，才知道交往對象都全部中標，對象有一個還是大學生，才剛滿20，另外有一個上班族女友已經為他墮胎過一次了，女方爸爸
# 9963
# 回應711
# 收藏
# 網路購物
# 亞東技術學院
# 2月5日 11:31
# 更/被買菜網送的體驗組嚇到了
# 來更一下好了，1.說葉配的麻煩幫我找廠商來付錢，謝謝，2.冷凍的火鍋料有四盒直接進冷凍沒入境，3.真的是沒有買菜過，家裡也都在超市買所以不知道市價，也真的完全不想進市場，尤其是現在這個情況，4.我們地
# 5726
# 回應90
# 收藏
# D
# 居家生活
# 好物研究員
# 1月24日 15:02
# 好物研究室
# 不怕久坐肩頸頂扣扣💪🏻『養身暖暖貼』 秋冬保養超easy‼️ 暖到不需要另一半來溫暖你
# 工作日天天出貨，火種價：養身暖暖貼 五袋 NTD $2205元，送沙棘肌活露 5 ml＊2＋沙棘多元修護精華3 ml＊1，養身暖暖貼 二袋 NTD $882元，送沙棘肌活露 5 ml＊1，養身暖暖貼
# 355
# 回應12
# 收藏
# 追星
# 國立中興大學
# 2月5日 14:20
# 謝和弦換老婆了！
# 這不是莉婭，莉婭是，這是，不知道是新的炮友還是新歡？幫 哭哭QQ，謝真的很垃圾⋯⋯
# 4750
# 回應333
# 收藏
# 時事
# 高雄醫學大學
# 2月5日 13:16
# 第一波武漢返台的台商，竟然有數十人不是"台灣人"??
# 2/4第一批返台的人回來了，但你知道返台名單是登機前才給我們嗎？你知道中國拒絕我們防疫人員先前往中國預備登機嗎？但台灣為了盡快接回國民，同意了，但最扯的是，有醫療需求，老弱婦孺竟然不是在第一批返台名單
# 4672
# 回應712
# 收藏
# 彩虹
# 匿名
# 2月5日 16:16
# 不讓女友剪短
# 最近我家小姊姊，一直喊著要剪短髮，你以為，是這種嗎（我最近的女神🤩，不是餒，是這種，至於為什麼我不願呢，請恕我娓娓道來，先是放幾張現在的長髮壓壓驚，欸不是你 去旁邊，如花與貌美如花，看書的花，看旁邊
# 4335
# 回應101
# 收藏
# 心情
# 匿名
# 2月5日 22:51
# 我對陳時中的第一印象
# 有人說我造神，因此我回覆一篇：先在禁墮胎的公投討論看到他出現，第一印象其實：誰啊？！，然後他說了這句很棒的話，幸好最後提案也被駁回了，可能這時候沒有很多人注意他，我也沒想到會在最近一直密集看到他出現在
# 4083
# 回應58
# 收藏
# D
# 居家生活
# 好物研究員
# 1月22日 15:27
# 好物研究室
# ＃男女都有 自帶體香二度回歸🌸研究員沒有偏心讓你跟擾人的異味說掰掰👋🏻
# 工作日天天出貨，火種價：Chappa 私密清潔保養沐浴露（女用）二入 NTD$700元（一罐只要350元），Chappa 私密清潔保養沐浴露（男用）二入 NTD$700元，Chappa 私密清潔保養沐
# 313
# 回應16
# 收藏
# 武漢肺炎
# 國立臺灣大學
# 2月5日 17:12
# 台商哀喊被當犯人
# 剛剛看到這篇快氣死，台灣費了那麼多的心思跟中國協商好不容易把你們接回來，或許這個隔離宿舍整個品質上不好，或許感覺像被當成犯人，但至少已經回到台灣 可以接受台灣的醫療了，拜託體諒一下吧 政府真的很辛苦了
# 3541
# 回應335
# 收藏
# 武漢肺炎
# 國立屏東科技大學
# 2月5日 15:53
# #轉貼 第十一例病患非本國國籍
# 更1-，有新聞出來了，太扯，當我們是阿共仔的收留地嗎，急需救援的病患竟然根本沒回來！，那些人也是臉皮有夠厚，就是待在中國怕死才跑來台灣，強烈要求下一批撤離人士若不在名單就丟回去，人民沒必要買單，更2-
# 3342
# 回應207
# 收藏
# 感情
# 匿名
# 2月5日 19:51
# 昨晚經歷了最痛的分手
# 我跟男友是大學同學，一直到大四快要結束了才在一起，他那時候自己創業賣東西，一開始規模小小的，我們有好多時間膩在一起，每逢我休假就一定會約會見面，（因為我家管嚴沒辦法跟他過夜或同居），那時候的我們好開心
# 3287
# 回應197
# 收藏
# D
# 美妝
# 好物研究員
# 12月23日 14:57
# 好物研究室
# 🙋‍♀️永別了痘痘👋BFFECT抗痘+保濕精華液👉不再迷信偏方，用專業科學對抗痘痘才是王道🔥
# app 右下角有立即購買，沒有的話記得更新 Dcard app，你可以開手機瀏覽器或是桌機上直接買也可以喔，️商品抵達超商自動觸發卡友系統信通知大家，️透過卡友信內的『訂單進度查詢』商品貨態，如逾期未
# 584
# 回應42
# 收藏
# 時事
# 國立臺灣海洋大學
# 2月5日 14:37
# 武漢肺炎 學校做法真的酷👍
# 學校3/2開學，暑假不延後做法是每堂課平均多上6分鐘，------------------，［補充］，學校正確公告是，老師自行補課，平均每堂課多上6分鐘，老師們可以選擇每堂課多上一點，也可以自行跟學生
# 3247
# 回應135
# 收藏
# 武漢肺炎
# 樹德科技大學
# 2月6日 10:14
# 根本國、共聯手害台灣😡😡😡
# 有人問：為什麼第二班撤僑專機取消？幹，因為中國不給你派飛機，不跟你台灣政府協商，最後運了一堆中國人配偶，跟中國關係特好的台商，還有個確診患者跟一飛機的病毒回來，你還敢再運第二趟？下次可能送你整機武漢肺
# 3093
# 回應256
# 收藏
# 心情
# 僑光科技大學
# 2月5日 15:35
# 不戴airpods是不是會被當異類
# 走在路上看到眾多airpods，不管是不是正的啦，幾乎都是人耳都戴，結果拿出我的無線耳機，通常會出現兩種人，1.「拿那個什麼雜牌耳機」「看都沒看過」2.「這是什麼？」會好奇聽一下 然後就回去繼續炫耀自
# 3048
# 回應602
# 收藏
# 有趣
# 國立澎湖科技大學
# 2月5日 23:07
# 跟youtuber拍照男友不開心?
# 后里燈會有一小區塊 可以搶先看，因為剛好要出門去接媽媽回家，就順道過去逛逛，結果在門口就遇到HowHow跟藍亦明！！！，第一次遇到youtuber當然把握機會拍照，拍完我就傳給男友跟他分享喜悅，結果他
# 2903
# 回應50
# 收藏
# 寵物
# 國立高雄餐旅大學
# 2月5日 14:35
# 限時動態的超級背殺
# 輔大的同學你家貓貓的這個背影燒到我了！！！，但是我忍不住幫他加了點料.....，登愣！，Zespri Zespri～好了不鬧了 輔大同學快出來交出貓貓正面照！
# 2687
# 回應36
# 收藏
# 心情
# 國立屏東大學
# 2月5日 12:34
# #幫高調 尊重原創 苡x吃貨抄襲or”類似”事件小整理
# 說個笑話 dcard是匿名平台（二更 太神啦 （更 補上疑似抄襲行為
# 2666
# 回應212
# 收藏
# 感情
# 匿名
# 2月5日 11:29
# 世上沒有後悔藥，也沒有回頭草等你吃
# 最近前男友找我復合，我都忘了跟他分手多久了，甚至某次跟朋友聊到，連他的名字我都想不起來，最近突然傳訊息給我，在我看來就像笑話一樣，我跟他分手可以說是很難看，他提的，還拿爸媽出來當藉口，說他們不喜歡我，
# 2388
# 回應47
# 收藏
# 有趣
# 中原大學
# 2月5日 19:40
# 更狂的小被被來了！
# 二更 哥哥回應在B158/ 比抹布還不如的垃⋯的小被被
# 2296
# 回應54
# 收藏
# 武漢肺炎
# 逢甲大學
# 2月5日 12:27
# 自私又無知的人真的很多
# 今天我姐姐去台酒排一組95%酒精來備用，現場有很多婆媽都在排隊，然而在排隊的過程中我姐聽到了以下的言論，普通人就不需要N95，買了也戴不住，現在又自作聰明，真的是自私又無知…
# 2226
# 回應64
# 收藏
# 感情
# 匿名
# 2月5日 15:51
# 和大叔在一起真的很幸福❤️
# 更：我不知道是不是大叔這個詞太讓人針對，我也說過跟年紀沒有絕對關係，只是剛好我跟閃差了12歲，以下很多事我都可以自己做，我單身的時候也能自己過得很好，但大叔出自於想保護我或照顧我所以有些貼心的行為，我
# 2047
# 回應221
# 收藏
# X
# 感情
# qwerty
# 2月5日 12:59
# 分手後復合 「更」
# 沒想過我的文章會上熱門 ，謝謝大家的祝福 ️，異國戀 遠距離雖然不被看好 不靠譜，但只要彼此的心裡還有對方 那就能好好走下去，希望大家都能找到自己的幸福。Ps：我和男友是玩狼人殺認識的，—————原文
# 1823
# 回應88
# 收藏
# 武漢肺炎
# 中山醫學大學
# 2月5日 14:13
# 幕後／看到名單傻眼！武漢返台班機數十人非台灣籍　安排者塞了中國籍配偶、家人
# 記者陶本和／台北報導，針對武漢肺炎，台北市家長會長協會總會長徐正文本來指稱5日會有第二批回台班機，但最後發現，這只是單向訊息，並非與我政府有關，導致滯留民眾被誤導。對此，參與相關連繫的台商還原實情，先
# 1712
# 回應349
# 收藏
# 牙齒矯正
# 輔英科技大學
# 2月5日 23:32
# ＃戽斗 正顎手術30天分享
# 意識到自己戽斗大約是國小五年級，家人都說戽斗會很有錢，小時候不懂事聽了還很得意呢～國中時被取了各種綽號，有的人還會故意把下巴凸出來模仿，最在意的是與人面對面說話時對方都把專注度放在我的下巴，讓我感到很
# 1448
# 回應56
# 收藏
# 時事
# 千葉大學
# 2月5日 22:35
# 今夜的101好暖心
# 更新：第一位確診病患已痊癒，親筆信感謝醫護人員，也希望未來可以好好照顧自己，台灣首例武漢病毒確診個案出院，親筆信感謝醫護人員，今天的101，有滿滿的正能量！，武漢肺炎爆發至今，所有的防疫、醫療人員一起
# 1430
# 回應24
# 收藏
# 武漢肺炎
# 國立政治大學
# 2月5日 23:27
# 徐正文有可能觸犯刑事罪啦
# 先說無罪推定，但是！！！！！！！，徐先生，除去偽造文書、傳染病防治法違反之外，你的行為可能已經觸犯兩岸人民關係條例第十五條的規定，是嚴重的刑事犯罪。兩岸人民關係條例，第十五條 下列行為不得為之，一、
# 1428
# 回應57
# 收藏
# M
# 寵物
# 延平北路最會養貓的男人
# 2月5日 21:17
# 跟機上盒談戀愛的白貓
# 最近天氣實在寒冷，搞的我家的貓，最近勾搭上機上盒，因為他會微微的發熱，憨吉徹底愛上他，直接往生式睡法，徹底睡死，還在上面伸懶腰，然後各種詭異動作，貴婦坐姿加上富有雙下巴，毛毛蟲模式，小白變成的棉花糖憨
# 1283
# 回應38
# 收藏
# X
# 追星
# 리치찌🌷🦔✨
# 2月5日 21:14
# 那些曾被說長得像Irene的人🌸
# 更，沒想到文章會引起這麼多討論哈哈哈，沒辦法一一回覆所以直接在這邊講一些些我自己小小的看法：1.，留言有提到不知道為什麼會有這麼多人推崇白菜的顏，其實也沒什麼原因吧 就是漂亮啊，大家都喜歡漂亮的人事物
# 1275
# 回應115
# 收藏
# 美食
# 國立中興大學
# 2月5日 17:24
# 全聯新蛋糕
# 每次去採買生活用品，一定會在蛋糕櫃前晃晃，在那邊演心理小劇場很久....，就在剛剛發現了新蛋糕！，巧克力蛋糕、覆盆子起司、原味起司，超想下手買的！！我看外觀應該是進口蛋糕～但這價格讓我有點縮....怕
# 1275
# 回應61
# 收藏
# 常見問題聯絡客服徵才商業合作
# window.$STATE={"adConfigs":{"store":{}},"app":{"isLogin":false,"amplitude":{"apiKey":"bfb03c251442ee56c07f655053aba20f","iosApiKey":"9e2fd13857b562968ac298aff9f6cbc5","androidApiKey":"cba46104d90853a7ce0afae9e2586bc5"},"fbthumb":{"host":"https:\u002F\u002Ffbthumb.dcard.tw\u002F"},"gateway":{"giftbox":"https:\u002F\u002Fgiftbox.dcard.tw\u002F","mercury":"http:\u002F\u002Fdcard-mercury\u002F","pptr":"https:\u002F\u002Fpptr.dcard.tw\u002F"},"depe":{"host":"https:\u002F\u002Fembed.dcard.tw\u002F"},"host":"www.dcard.tw","dcardCC":false,"isGoogleBot":false,"forumCategories":{"ruleKey":"web_TW_noLogin","configName":"MEMBER_AND_GUEST_TW_WEB","all":[{"uiType":"dropdown","alias":"all","name":"全部","listType":"legacy","uiPayload":{"dropdownItems":[{"uiType":"button","alias":"hot","name":"熱門","listType":"legacy"},{"uiType":"button","alias":"latest","name":"最新","listType":"legacy"}]}},{"uiType":"button","alias":"subscribe","name":"追蹤","listType":"legacy"}],"forum":[{"uiType":"button","alias":"hot","name":"熱門","listType":"legacy"},{"uiType":"button","alias":"latest","name":"最新","listType":"legacy"},{"uiType":"button","alias":"rule","name":"板規","listType":"rule"}]},"service":"dcard-web","isProduction":true},"banners":{},"collections":{"store":[]},"commentEdit":{"store":{}},"commentFloors":{"store":{}},"commentPagination":{"store":{}},"comments":{"store":[]},"configs":{"store":{}},"countries":{"store":{}},"darsys":{"id":{},"posts":{}},"dcard":{},"departments":{"store":[]},"emails":{"store":[]},"errors":{"posts":{}},"fastpass":{},"feeds":{"subscriptions":[]},"form":{"headerSearch":{"values":{"query":""},"initial":{"query":""},"syncErrors":{"query":"此欄位為必填。"}}},"forumPagination":{"store":{}},"forumBulletins":{},"forumGroups":{"status":{"moderator":true,"common":true}},"forums":{"store":[{"availableLayouts":["classic"],"limitStage":0,"fullyAnonymous":false,"topics":["午夜實驗室"],"canUseNickname":true,"mediaThreshold":{},"name":"午夜實驗室","postThumbnail":{"size":"small"},"invisible":true,"updatedAt":"2018-11-05T03:24:32.914Z","postCount":{"last30Days":1},"canPost":false,"alias":"midnightlab","ignorePost":false,"subscriptionCount":1840,"nsfw":false,"read":false,"shouldCategorized":false,"limitCountries":[],"subscribed":false,"postTitlePlaceholder":"","id":"7f125e07-4460-4ea5-80b5-33f0e9aafa0c","createdAt":"2016-05-14T19:15:15.698Z","titlePlaceholder":"","subcategories":[],"favorite":false,"description":"午夜實驗室10\u002F6、10\u002F7即將在華山登場！這裏提供大家交流活動資訊與討論，請大家要遵守 Dcard 板規喔！","isSchool":false},{"availableLayouts":["classic"],"limitStage":0,"fullyAnonymous":false,"topics":[],"canUseNickname":true,"mediaThreshold":{},"name":"時光膠囊","postThumbnail":{"size":"small"},"invisible":true,"updatedAt":"2020-01-02T02:23:04.836Z","postCount":{"last30Days":6},"canPost":false,"alias":"timecapsule","ignorePost":true,"subscriptionCount":3041,"nsfw":false,"read":false,"shouldCategorized":false,"limitCountries":[],"subscribed":false,"postTitlePlaceholder":"","id":"c0ed3f99-ed1c-49a8-b413-ed5e925aafe4","createdAt":"2016-05-14T20:15:15.698Z","titlePlaceholder":"","subcategories":[],"favorite":false,"description":"寫下你的新年新希望，一年後將收到「時光膠囊」，幫助你檢視這一年達成了多少目標，實現了多少願望！","isSchool":false},{"availableLayouts":["classic"],"limitStage":0,"fullyAnonymous":false,"topics":["我是媽寶我驕傲","曬媽媽","母親節蛋糕","康乃馨","母親節花束","我愛媽媽","母親節禮物","媽媽我愛你","媽媽","母親節大餐","母親節檔期"],"canUseNickname":true,"mediaThreshold":{},"name":"母親節","postThumbnail":{"size":"small"},"invisible":true,"updatedAt":"2018-05-15T08:04:10.308Z","postCount":{"last30Days":0},"canPost":false,"alias":"mother","ignorePost":false,"subscriptionCount":423,"nsfw":false,"read":false,"shouldCategorized":false,"limitCountries":[],"subscribed":false,"postTitlePlaceholder":"","id":"cc2164ae-88cd-466d-b11b-19e4b1f6f78c","createdAt":"2016-05-14T22:15:15.698Z","titlePlaceholder":"","subcategories":[],"favorite":false,"description":"Dcard 母親節限定板，告訴媽媽我愛妳！","isSchool":false},{"availableLayouts":["classic"],"heroImage":{"url":"https:\u002F\u002Fmegapx-assets.dcard.tw\u ...
